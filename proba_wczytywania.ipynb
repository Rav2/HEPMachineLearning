# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import read_tree as rt
# Out:
# Welcome to JupyROOT 6.15/01

# %%
zbior=rt.read_tree(file_name="data_rootowe_obrobione/MT_GluGlu.root")
# Out:
# [ML]	Opening root file for python conversion.
# [ML]	Reading data from TTree.
# [ML]	Conversion to python successful!

# %%
legs, jets, global_params, properties=zbior

# %%
len(legs[0][0])
# Out:
# 59083

# %%
zbior2=rt.read_tree(file_name="data_rootowe_obrobione/MT_WJets.root")
# Out:
# [ML]	Opening root file for python conversion.
# [ML]	Reading data from TTree.
# [ML]	Conversion to python successful!

# %%
legs2, jets2, global_params2, properties2=zbior2

# %%
len(legs2[0][0])
# Out:
# 3087
